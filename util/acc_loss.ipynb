# %%
import numpy as np
import matplotlib.pyplot as plt

acc0 = np.empty([0],dtype='float')
with open("old_2e_50000_32_1_ALR_acc.txt", 'r') as f:
    for line in f:
        acc0 = np.append(acc0, float(line.rstrip('\n')))
        
acc1 = np.empty([0],dtype='float')
with open("old_2e_50000_32_1_acc.txt", 'r') as f:
    for line in f:
        acc1 = np.append(acc1, float(line.rstrip('\n')))
        
acc2 = np.empty([0],dtype='float')
with open("new_2e_50000_16_1_acc.txt", 'r') as f:
    for line in f:
        acc2 = np.append(acc2, float(line.rstrip('\n')))
        
acc3 = np.empty([0],dtype='float')
with open("new_2e_50000_16_2_acc.txt", 'r') as f:
    for line in f:
        acc3 = np.append(acc3, float(line.rstrip('\n')))
        
acc4 = np.empty([0],dtype='float')
with open("new_2e_50000_32_1_acc.txt", 'r') as f:
    for line in f:
        acc4 = np.append(acc4, float(line.rstrip('\n')))
        
acc5 = np.empty([0],dtype='float')
with open("old_2e_50000_16_1_acc.txt", 'r') as f:
    for line in f:
        acc5 = np.append(acc5, float(line.rstrip('\n')))


fs = 16
font = {'family': 'Arial',
        'weight': 'normal',
        'size': fs,
        }

fig = plt.figure(figsize=(5,3), dpi=150)
plt.semilogx(range(len(acc0)), acc0, label='old_adaptive LR')        
plt.semilogx(range(len(acc1)), acc1, label='old_65_1')
plt.semilogx(range(len(acc5)), acc5, label='old_33_1')
plt.semilogx(range(len(acc4)), acc4, label='new_65_1')
plt.semilogx(range(len(acc2)), acc2, label='new_33_1')
plt.semilogx(range(len(acc3)), acc3, label='new_33_2')
plt.xlabel('Iteration #', fontdict=font)
plt.ylabel('Accuracy', fontdict=font)
plt.legend(loc='lower right', prop={'size': fs-5}, frameon=False)
plt.show()

# %%
loss0 = np.empty([0],dtype='float')
with open("old_2e_50000_32_1_ALR_loss.txt", 'r') as f:
    for line in f:
        loss0 = np.append(loss0, float(line.rstrip('\n')))
        
loss1 = np.empty([0],dtype='float')
with open("old_2e_50000_32_1_loss.txt", 'r') as f:
    for line in f:
        loss1 = np.append(loss1, float(line.rstrip('\n')))
        
loss2 = np.empty([0],dtype='float')
with open("new_2e_50000_16_1_loss.txt", 'r') as f:
    for line in f:
        loss2 = np.append(loss2, float(line.rstrip('\n')))
        
loss3 = np.empty([0],dtype='float')
with open("new_2e_50000_16_2_loss.txt", 'r') as f:
    for line in f:
        loss3 = np.append(loss3, float(line.rstrip('\n')))
        
loss4 = np.empty([0],dtype='float')
with open("new_2e_50000_32_1_loss.txt", 'r') as f:
    for line in f:
        loss4 = np.append(loss4, float(line.rstrip('\n')))
        
loss5 = np.empty([0],dtype='float')
with open("old_2e_50000_16_1_loss.txt", 'r') as f:
    for line in f:
        loss5 = np.append(loss5, float(line.rstrip('\n')))



fig = plt.figure(figsize=(5,3), dpi=150)
plt.plot(loss0, label='old_ALR')        
plt.plot(loss1, label='old_65_1')
plt.plot(loss5, label='old_33_1')
plt.plot(loss4, label='new_65_1')
plt.plot(loss2, label='new_33_1')
plt.plot(loss3, label='new_33_2')
plt.xlabel('Iteration #', fontdict=font)
plt.ylabel('Loss', fontdict=font)
plt.legend(loc='upper right', prop={'size': fs-5}, frameon=False)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

loss0 = np.empty([0],dtype='float')
with open("old_2e_60000_32_1_base_loss.txt", 'r') as f:
    for line in f:
        loss0 = np.append(loss0, float(line.rstrip('\n')))
        
loss1 = np.empty([0],dtype='float')
with open("old_2e_60000_32_1_loss.txt", 'r') as f:
    for line in f:
        loss1 = np.append(loss1, float(line.rstrip('\n')))
        
loss2 = np.empty([0],dtype='float')
with open("new_2e_60000_32_1_loss.txt", 'r') as f:
    for line in f:
        loss2 = np.append(loss2, float(line.rstrip('\n')))

loss3 = np.empty([0],dtype='float')
with open("new_2e_60000_16_1_loss.txt", 'r') as f:
    for line in f:
        loss3 = np.append(loss3, float(line.rstrip('\n')))
               
loss4 = np.empty([0],dtype='float')
with open("new_2e_60000_16_2_loss.txt", 'r') as f:
    for line in f:
        loss4 = np.append(loss4, float(line.rstrip('\n')))

# %%
fs = 12
font = {'family': 'Arial',
        'weight': 'normal',
        'size': fs,
        }
fig = plt.figure(figsize=(4,3), dpi=160)
plt.plot(loss0, label='base')        
#plt.plot(loss1, label='old_65_1')
plt.plot(loss2, label='new_65_1')
plt.plot(loss3, label='new_33_1')
plt.plot(loss4, label='new_33_2')
plt.xlabel('Batch #', fontdict=font)
plt.ylabel('Loss', fontdict=font)
plt.legend(loc='upper right', prop={'size': fs-2}, frameon=False)
plt.show()

# %%
acc0 = np.empty([0],dtype='float')
with open("old_2e_60000_32_1_base_acc.txt", 'r') as f:
    for line in f:
        acc0 = np.append(acc0, float(line.rstrip('\n')))
        
acc1 = np.empty([0],dtype='float')
with open("old_2e_60000_32_1_acc.txt", 'r') as f:
    for line in f:
        acc1 = np.append(acc1, float(line.rstrip('\n')))
        
acc2 = np.empty([0],dtype='float')
with open("new_2e_60000_32_1_acc.txt", 'r') as f:
    for line in f:
        acc2 = np.append(acc2, float(line.rstrip('\n')))

acc3 = np.empty([0],dtype='float')
with open("new_2e_60000_16_1_acc.txt", 'r') as f:
    for line in f:
        acc3 = np.append(acc3, float(line.rstrip('\n')))
        
        
acc4 = np.empty([0],dtype='float')
with open("new_2e_60000_16_2_acc.txt", 'r') as f:
    for line in f:
        acc4 = np.append(acc4, float(line.rstrip('\n')))

# %%
fig = plt.figure(figsize=(4,3), dpi=150)
plt.semilogx(range(len(acc0)), acc0, label='old_base')        
#plt.semilogx(range(len(acc1)), acc1, label='old_65_1')
plt.semilogx(range(len(acc2)), acc2, label='new_65_1')
plt.semilogx(range(len(acc3)), acc3, label='new_33_1')
plt.semilogx(range(len(acc4)), acc4, label='new_33_2')

plt.xlabel('Batch #', fontdict=font)
plt.ylabel('Training Accuracy', fontdict=font)
plt.legend(loc='lower right', prop={'size': fs-2}, frameon=False)
plt.show()
